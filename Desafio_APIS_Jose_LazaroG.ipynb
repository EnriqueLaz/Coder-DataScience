# %% [markdown]
# <a id='part4'></a>
#
# ## Laboratorio 4

# %% [markdown]
# Actividades:
# 1. Conectarse a la cuenta de Twitter de la Municipalidad de Lima.
# 2. Extraer los tweets del mes de Enero y guardarla en un data frame el contenido y fecha de publicación.

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install facebook-sdk
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tweepy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import facebook 
import tweepy
import numpy as np 
import requests

# %%
# recovering security info
consumer_key = 'eMcnfrsrAgghHJCCBdP8QStYj'
consumer_secret = 'M2FwH7ARB8MK6hq0n8HTrVErWanAsTST0nkmw11VfvuMjn8fel'
access_token = '587863980-j6aJNJaXotnCuYF5rBZ8myUYF8kCet61E5sgWWHC'
access_token_secret = 'TbSQ6OVufSk0LH6iiRpSAJBwffggEOR2Ah1ToXRQghRIV'

# %%
# using security info:
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api=tweepy.API(auth, 
               wait_on_rate_limit=True,
               wait_on_rate_limit_notify=True,
               parser=tweepy.parsers.JSONParser())

# %%
# getting the tweets from a user:

tweets = api.user_timeline(screen_name = 'MuniLima', #cuenta
                           count = 1000, #número de tweets 
                           include_rts = True) #True: incluye rts

# %%
tweets[0:2]
# Out:
# [{'created_at': 'Sat Feb 06 22:37:21 +0000 2021',
#   'id': 1358183023028625408,
#   'id_str': '1358183023028625408',
#   'text': '💧 Hoy iniciamos las acciones de abastecimiento de agua potable para beneficiar a vecinos de las zonas más vulnerabl… https://t.co/HqmOXdbO9N',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/HqmOXdbO9N',
#      'expanded_url': 'https://twitter.com/i/web/status/1358183023028625408',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 158871696,
#    'id_str': '158871696',
#    'name': 'Municipalidad de Lima',
#    'screen_name': 'MuniLima',
# ...

# %%
aTweet = tweets[0]

for field in aTweet.keys():
    print (field)
# Out:
# created_at
# id
# id_str
# text
# truncated
# entities
# source
# in_reply_to_status_id
# in_reply_to_status_id_str
# in_reply_to_user_id
# in_reply_to_user_id_str
# in_reply_to_screen_name
# user
# geo
# coordinates
# place
# contributors
# is_quote_status
# retweet_count
# favorite_count
# favorited
# retweeted
# possibly_sensitive
# lang

# %%
contenido = [t['text'] for t in tweets]
fecha = [t['created_at'] for t in tweets]

# %%
resultado = pd.DataFrame({'Contenido':contenido,
                         'FechaDePublicacion':fecha})
resultado.head()
# Out:
#                                            Contenido  \
# 0  💧 Hoy iniciamos las acciones de abastecimiento...
# 1  👩🏽‍🔬 ¡Pasa la voz y súmate a nuestras activida...
# 2  Cuando estornudes no te quites la mascarilla, ...
# 3  Durante el periodo de cuarentena, garantizamos...
# 4  @genayo @MimpPeru @EsSaludPeru Hola, Genaro. M...
#
#              Fecha de publicacion
# 0  Sat Feb 06 22:37:21 +0000 2021
# 1  Sat Feb 06 22:09:36 +0000 2021
# 2  Sat Feb 06 21:30:00 +0000 2021
# 3  Sat Feb 06 21:29:15 +0000 2021
# 4  Sat Feb 06 19:21:19 +0000 2021

# %%
tiempo = pd.to_datetime(fecha)
tiempo
# Out:
# DatetimeIndex(['2021-02-06 22:37:21+00:00', '2021-02-06 22:09:36+00:00',
#                '2021-02-06 21:30:00+00:00', '2021-02-06 21:29:15+00:00',
#                '2021-02-06 19:21:19+00:00', '2021-02-06 19:20:15+00:00',
#                '2021-02-06 17:30:00+00:00', '2021-02-06 17:00:00+00:00',
#                '2021-02-06 16:06:21+00:00', '2021-02-06 16:00:01+00:00',
#                ...
#                '2021-01-28 21:30:00+00:00', '2021-01-28 21:00:00+00:00',
#                '2021-01-28 18:42:38+00:00', '2021-01-28 17:40:29+00:00',
#                '2021-01-28 16:08:09+00:00', '2021-01-28 16:03:46+00:00',
#                '2021-01-28 15:45:00+00:00', '2021-01-28 15:13:02+00:00',
#                '2021-01-28 00:15:12+00:00', '2021-01-28 00:15:11+00:00'],
#               dtype='datetime64[ns, UTC]', length=200, freq=None)

# %%
resultado = pd.DataFrame({'Contenido':contenido,
                         'FechaDePublicacion':tiempo})
resultado.head()
# Out:
#                                            Contenido        FechaDePublicacion
# 0  💧 Hoy iniciamos las acciones de abastecimiento... 2021-02-06 22:37:21+00:00
# 1  👩🏽‍🔬 ¡Pasa la voz y súmate a nuestras activida... 2021-02-06 22:09:36+00:00
# 2  Cuando estornudes no te quites la mascarilla, ... 2021-02-06 21:30:00+00:00
# 3  Durante el periodo de cuarentena, garantizamos... 2021-02-06 21:29:15+00:00
# 4  @genayo @MimpPeru @EsSaludPeru Hola, Genaro. M... 2021-02-06 19:21:19+00:00

# %%
newdata = resultado[resultado['FechaDePublicacion'].dt.month == 1]
newdata
# Out:
#                                              Contenido  \
# 157  @_AguilarVictor @Carlo_Angelesm Para aclarar q...
# 158  @Carlo_Angelesm Estimado regidor, el Parque de...
# 159  @_AguilarVictor @cadnep @udealima @LimaesNuest...
# 160  🍎🥗 Cuidar tu alimentación también es una forma...
# 161  ¡Aprovecha esta oportunidad! 🤓\n\n🙌🏽 Ofrecemos...
# 162  Desde la madrugada de este primer día de cuare...
# 163  👩‍💻 ¡Atento emprendedor! Mercado De Lima es la...
# 164  Durante el primer día de la cuarentena dictada...
# 165  🩺 Los establecimientos de @SisolSalud seguirán...
# 166  🚦 En enero 2021, realizamos más de 280 reparac...
# 167  🤲 Cerca de mil vecinos del Cercado se benefici...
# 168  💪🏽 ¡Ya iniciamos los talleres virtuales de est...
# 169  🛍 ¡Apoya a los emprendedores de la ciudad!\n📲🤲...
# 170  🤝 Nuevos convenios para la prevención, reducci...
# 171  🤝💞🍲 El #COVID19 sigue entre nosotros. Por ello...
# 172  ¡Atención! 👨‍💻Participa de la segunda edición ...
# ...

# %%
newdata = resultado[tiempo.month == 1]
newdata
# Out:
#                                              Contenido  \
# 157  @_AguilarVictor @Carlo_Angelesm Para aclarar q...
# 158  @Carlo_Angelesm Estimado regidor, el Parque de...
# 159  @_AguilarVictor @cadnep @udealima @LimaesNuest...
# 160  🍎🥗 Cuidar tu alimentación también es una forma...
# 161  ¡Aprovecha esta oportunidad! 🤓\n\n🙌🏽 Ofrecemos...
# 162  Desde la madrugada de este primer día de cuare...
# 163  👩‍💻 ¡Atento emprendedor! Mercado De Lima es la...
# 164  Durante el primer día de la cuarentena dictada...
# 165  🩺 Los establecimientos de @SisolSalud seguirán...
# 166  🚦 En enero 2021, realizamos más de 280 reparac...
# 167  🤲 Cerca de mil vecinos del Cercado se benefici...
# 168  💪🏽 ¡Ya iniciamos los talleres virtuales de est...
# 169  🛍 ¡Apoya a los emprendedores de la ciudad!\n📲🤲...
# 170  🤝 Nuevos convenios para la prevención, reducci...
# 171  🤝💞🍲 El #COVID19 sigue entre nosotros. Por ello...
# 172  ¡Atención! 👨‍💻Participa de la segunda edición ...
# ...
